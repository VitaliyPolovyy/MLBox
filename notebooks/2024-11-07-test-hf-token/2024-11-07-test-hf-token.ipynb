# %%
import dotenv

# %%
dotenv.load_dotenv()
# Out:
# True

# %%
import os
hf_token = os.getenv("HF_TOKEN")

# %%
print(hf_token)

if hf_token is None:
    print("HF_TOKEN not set")
    exit(1)
# Out:
# 12345
